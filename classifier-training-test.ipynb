# %%
! pip install optax
# Out:
# Requirement already satisfied: optax in /opt/conda/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: absl-py>=0.7.1 in /opt/conda/lib/python3.9/site-packages (from optax) (1.4.0)
# Requirement already satisfied: numpy>=1.18.0 in /opt/conda/lib/python3.9/site-packages (from optax) (1.23.5)
# Requirement already satisfied: typing-extensions>=3.10.0 in /opt/conda/lib/python3.9/site-packages (from optax) (4.4.0)
# Requirement already satisfied: chex>=0.1.5 in /opt/conda/lib/python3.9/site-packages (from optax) (0.1.5)
# Requirement already satisfied: jax>=0.1.55 in /opt/conda/lib/python3.9/site-packages (from optax) (0.4.2)
# Requirement already satisfied: jaxlib>=0.1.37 in /opt/conda/lib/python3.9/site-packages (from optax) (0.4.2)
# Requirement already satisfied: toolz>=0.9.0 in /opt/conda/lib/python3.9/site-packages (from chex>=0.1.5->optax) (0.12.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /opt/conda/lib/python3.9/site-packages (from chex>=0.1.5->optax) (0.1.8)
# Requirement already satisfied: opt-einsum in /opt/conda/lib/python3.9/site-packages (from jax>=0.1.55->optax) (3.3.0)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.9/site-packages (from jax>=0.1.55->optax) (1.10.0)

# %%
# !pip install qiskit_dynamics
# Out:
# Collecting qiskit_dynamics
#   Downloading qiskit_dynamics-0.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 3.1 MB/s eta 0:00:0000:01
# Requirement already satisfied: qiskit-terra>=0.16.0 in /opt/conda/lib/python3.9/site-packages (from qiskit_dynamics) (0.22.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.9/site-packages (from qiskit_dynamics) (1.23.5)
# Collecting multiset>=3.0.1
#   Downloading multiset-3.0.1-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: scipy>=1.4 in /opt/conda/lib/python3.9/site-packages (from qiskit_dynamics) (1.10.0)
# Requirement already satisfied: matplotlib>=3.0 in /opt/conda/lib/python3.9/site-packages (from qiskit_dynamics) (3.6.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0->qiskit_dynamics) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0->qiskit_dynamics) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0->qiskit_dynamics) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0->qiskit_dynamics) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0->qiskit_dynamics) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0->qiskit_dynamics) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0->qiskit_dynamics) (3.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.0->qiskit_dynamics) (1.0.7)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra>=0.16.0->qiskit_dynamics) (0.3.6)
# Requirement already satisfied: sympy>=1.3 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra>=0.16.0->qiskit_dynamics) (1.11.1)
# Requirement already satisfied: retworkx>=0.11.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra>=0.16.0->qiskit_dynamics) (0.12.1)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra>=0.16.0->qiskit_dynamics) (1.1.1)
# Requirement already satisfied: symengine>=0.9 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra>=0.16.0->qiskit_dynamics) (0.9.2)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra>=0.16.0->qiskit_dynamics) (5.9.0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra>=0.16.0->qiskit_dynamics) (4.1.1)
# Requirement already satisfied: ply>=3.10 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra>=0.16.0->qiskit_dynamics) (3.11)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->qiskit_dynamics) (1.16.0)
# Requirement already satisfied: rustworkx==0.12.1 in /opt/conda/lib/python3.9/site-packages (from retworkx>=0.11.0->qiskit-terra>=0.16.0->qiskit_dynamics) (0.12.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from stevedore>=3.0.0->qiskit-terra>=0.16.0->qiskit_dynamics) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy>=1.3->qiskit-terra>=0.16.0->qiskit_dynamics) (1.2.1)
# Installing collected packages: multiset, qiskit_dynamics
# Successfully installed multiset-3.0.1 qiskit_dynamics-0.3.2

# %%
import random
from typing import Tuple

import optax
import jax.numpy as jnp
import jax
import numpy as np

from utils.utils import simulate, histogram_to_category

from sklearn.model_selection import train_test_split

# Import the circuits
from circuits.encoderFRQI import encode as frqi
from circuits.encoderBASIC import encode as basic_encoder

from circuits.weightsCircuit import encode as weight_layer

def run_training(X, y, encoder_fn, classifier_fn, backend='qiskit'):
    
    n_layers = 1
    batch_size = 32
    epochs = 1_000
    
    def circuit_wrapper(x: jnp.ndarray, params: jnp.ndarray) -> jnp.ndarray:
        print(params['w'])
        print(params['w'].shape)
        #print(np.array(w[:][0]))
        categories = []
        for i_ in range(batch_size):
            circuit = encoder_fn(jnp.array(x[i_]))
            print(type(params['w']))
            #print(type(np.array(params['w'])))
            classifier = classifier_fn(jnp.array(params['w']))

            nq1 = circuit.width()
            nq2 = classifier.width()

            nq = max(nq1, nq2)
            qc = qiskit.QuantumCircuit(nq)
            qc.append(circuit.to_instruction(), list(range(nq1)))
            qc.append(classifier.to_instruction(), list(range(nq2)))

            histogram = simulate(qc)
            categories.append[histogram_to_category(histogram)]

        return categories

    
    def loss(params: optax.Params, batch: jnp.ndarray, labels: jnp.ndarray) -> jnp.ndarray:
        predictions = circuit_wrapper(batch, params)
        
        y_pred = jax.nn.one_hot(y % 2, 2).astype(jnp.float32).reshape(len(labels), 2)
        loss_value = optax.sigmoid_binary_cross_entropy(y_hat, labels).sum(axis=-1)

        return loss_value.mean()

    def fit(params: optax.Params, optimizer: optax.GradientTransformation) -> optax.Params:
        opt_state = optimizer.init(params)

        #@jax.jit
        def step(params, opt_state, batch, labels):
            loss_value, grads = jax.value_and_grad(loss)(params, batch, labels)
            updates, opt_state = optimizer.update(grads, opt_state, params)
            params = optax.apply_updates(params, updates)
            return params, opt_state, loss_value

        for i in range(epochs):

            batch_index = np.random.randint(0, len(y), (batch_size,))
            x_train_batch = X[batch_index]
            y_train_batch = y[batch_index]


            params, opt_state, loss_value = step(params, opt_state, x_train_batch, y_train_batch)
            losses.append(loss_value)
            if i % 100 == 0:
                print(f'step {i}, loss: {loss_value}')

            return params, losses

    
    initial_params = {
        'w': jax.random.normal(shape=[16, n_layers], key=jax.random.PRNGKey(0)),
    }
    
    optimizer = optax.adam(learning_rate=1e-2)
    
    optimal_params, losses = fit(initial_params, optimizer)
    
    optimal_classifier = classifier_fn(optimal_params)
    
    return optimal_classifier, losses

# %%
X = np.load('data/images.npy')
y = np.load('data/labels.npy')

X_reshape = np.reshape(X, (len(X), 28*28))
y_reshape = jax.nn.one_hot(y % 2, 2).astype(jnp.float32).reshape(2000, 2)

X_train, X_test, y_train, y_test = train_test_split(X_reshape, y_reshape, test_size=0.2, random_state=42)

circuit_weights, losses = run_training(X_train, y_train, frqi, weight_layer)
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Traced<ConcreteArray([[ 0.08482574]
#  [ 1.9097648 ]
#  [ 0.29561743]
#  [ 1.120948  ]
#  [ 0.33432344]
#  [-0.82606775]
#  [ 0.6481277 ]
#  [ 1.0434873 ]
#  [-0.7824839 ]
#  [-0.4539462 ]
#  [ 0.6297971 ]
#  [ 0.81524646]
#  [-0.32787678]
#  [-1.1234448 ]
#  [-1.6607416 ]
#  [ 0.27290547]], dtype=float32)>with<JVPTrace(level=2/0)> with
#   primal = Array([[ 0.08482574],
#        [ 1.9097648 ],
#        [ 0.29561743],
#        [ 1.120948  ],
#        [ 0.33432344],
#        [-0.82606775],
#        [ 0.6481277 ],
#        [ 1.0434873 ],
#        [-0.7824839 ],
#        [-0.4539462 ],
#        [ 0.6297971 ],
#        [ 0.81524646],
#        [-0.32787678],
#        [-1.1234448 ],
#        [-1.6607416 ],
#        [ 0.27290547]], dtype=float32)
#   tangent = Traced<ShapedArray(float32[16,1])>with<JaxprTrace(level=1/0)> with
#     pval = (ShapedArray(float32[16,1]), None)
#     recipe = LambdaBinding()
# (16, 1)
# <class 'jax.interpreters.ad.JVPTracer'>
# <class 'jax.interpreters.ad.JVPTrace'>
# ---------------------------------------------------------------------------
# CircuitError                              Traceback (most recent call last)
# Cell In[2], line 9
#       5 y_reshape = jax.nn.one_hot(y % 2, 2).astype(jnp.float32).reshape(2000, 2)
#       7 X_train, X_test, y_train, y_test = train_test_split(X_reshape, y_reshape, test_size=0.2, random_state=42)
# ----> 9 circuit_weights, losses = run_training(X_train, y_train, frqi, weight_layer)
#
# Cell In[1], line 89, in run_training(X, y, encoder_fn, classifier_fn, backend)
#      83 initial_params = {
#      84     'w': jax.random.normal(shape=[16, n_layers], key=jax.random.PRNGKey(0)),
#      85 }
#      87 optimizer = optax.adam(learning_rate=1e-2)
# ---> 89 optimal_params, losses = fit(initial_params, optimizer)
#      91 optimal_classifier = classifier_fn(optimal_params)
#      93 return optimal_classifier, losses
#
# Cell In[1], line 75, in run_training.<locals>.fit(params, optimizer)
#      71 x_train_batch = X[batch_index]
#      72 y_train_batch = y[batch_index]
# ---> 75 params, opt_state, loss_value = step(params, opt_state, x_train_batch, y_train_batch)
#      76 losses.append(loss_value)
#      77 if i % 100 == 0:
#
# Cell In[1], line 63, in run_training.<locals>.fit.<locals>.step(params, opt_state, batch, labels)
#      62 def step(params, opt_state, batch, labels):
# ---> 63     loss_value, grads = jax.value_and_grad(loss)(params, batch, labels)
#      64     updates, opt_state = optimizer.update(grads, opt_state, params)
#      65     params = optax.apply_updates(params, updates)
#
#     [... skipping hidden 8 frame]
#
# Cell In[1], line 51, in run_training.<locals>.loss(params, batch, labels)
#      50 def loss(params: optax.Params, batch: jnp.ndarray, labels: jnp.ndarray) -> jnp.ndarray:
# ---> 51     predictions = circuit_wrapper(batch, params)
#      53     y_pred = jax.nn.one_hot(y % 2, 2).astype(jnp.float32).reshape(len(labels), 2)
#      54     loss_value = optax.sigmoid_binary_cross_entropy(y_hat, labels).sum(axis=-1)
#
# Cell In[1], line 34, in run_training.<locals>.circuit_wrapper(x, params)
#      32 print(type(params['w']))
#      33 #print(type(np.array(params['w'])))
# ---> 34 classifier = classifier_fn(jnp.array(params['w']))
#      36 nq1 = circuit.width()
#      37 nq2 = classifier.width()
#
# File ~/2023_IonQ_Remote/circuits/weightsCircuit.py:17, in encode(w)
#      15 print(type(w._trace))
#      16 for i in range(qubits):
# ---> 17     qc.ry(pi*w[i],i)
#      19 qc=transpile(qc)
#      20 return qc
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/quantumcircuit.py:3286, in QuantumCircuit.ry(self, theta, qubit, label)
#    3272 """Apply :class:`~qiskit.circuit.library.RYGate`.
#    3273
#    3274 For the full matrix form of this gate, see the underlying gate documentation.
#    (...)
#    3282     A handle to the instructions created.
#    3283 """
#    3284 from .library.standard_gates.ry import RYGate
# -> 3286 return self.append(RYGate(theta, label=label), [qubit], [])
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/library/standard_gates/ry.py:54, in RYGate.__init__(self, theta, label)
#      52 def __init__(self, theta: ParameterValueType, label: Optional[str] = None):
#      53     """Create new RY gate."""
# ---> 54     super().__init__("ry", 1, [theta], label=label)
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/gate.py:38, in Gate.__init__(self, name, num_qubits, params, label)
#      29 """Create a new gate.
#      30
#      31 Args:
#    (...)
#      35     label: An optional label for the gate.
#      36 """
#      37 self.definition = None
# ---> 38 super().__init__(name, num_qubits, 0, params, label=label)
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/instruction.py:105, in Instruction.__init__(self, name, num_qubits, num_clbits, params, duration, unit, label)
#     102 self._duration = duration
#     103 self._unit = unit
# --> 105 self.params = params
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/instruction.py:223, in Instruction.params(self, parameters)
#     221     self._params.append(single_param)
#     222 else:
# --> 223     self._params.append(self.validate_parameter(single_param))
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/gate.py:234, in Gate.validate_parameter(self, parameter)
#     232     return parameter.item()
#     233 else:
# --> 234     raise CircuitError(f"Invalid param type {type(parameter)} for gate {self.name}.")
#
# CircuitError: "Invalid param type <class 'jax.interpreters.ad.JVPTracer'> for gate ry."
