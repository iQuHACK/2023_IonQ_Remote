# %%
! pip install optax
# Out:
# Collecting optax
#   Using cached optax-0.1.4-py3-none-any.whl (154 kB)
# Collecting chex>=0.1.5
#   Using cached chex-0.1.5-py3-none-any.whl (85 kB)
# Collecting jaxlib>=0.1.37
#   Using cached jaxlib-0.4.2-cp39-cp39-manylinux2014_x86_64.whl (71.9 MB)
# Collecting absl-py>=0.7.1
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: typing-extensions>=3.10.0 in /opt/conda/lib/python3.9/site-packages (from optax) (4.4.0)
# Requirement already satisfied: numpy>=1.18.0 in /opt/conda/lib/python3.9/site-packages (from optax) (1.23.5)
# Collecting jax>=0.1.55
#   Using cached jax-0.4.2-py3-none-any.whl
# Collecting dm-tree>=0.1.5
#   Using cached dm_tree-0.1.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (153 kB)
# Collecting toolz>=0.9.0
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Collecting opt-einsum
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.9/site-packages (from jax>=0.1.55->optax) (1.10.0)
# Installing collected packages: dm-tree, toolz, opt-einsum, absl-py, jaxlib, jax, chex, optax
# Successfully installed absl-py-1.4.0 chex-0.1.5 dm-tree-0.1.8 jax-0.4.2 jaxlib-0.4.2 opt-einsum-3.3.0 optax-0.1.4 toolz-0.12.0

# %%
import random
from typing import Tuple

import optax
import jax.numpy as jnp
import jax
import numpy as np

from utils.utils import simulate, histogram_to_category

from sklearn.model_selection import train_test_split

# Import the circuits
from circuits.encoderFRQI import encode as frqi
from circuits.encoderBASIC import encode as basic_encoder

from circuits.weightsCircuit import encode as weight_layer

def run_training(X, y, encoder_fn, classifier_fn, backend='qiskit'):
    
    n_layers = 2
    batch_size = 32
    epochs = 1_000
    
    def circuit_wrapper(x: jnp.ndarray, w: jnp.ndarray) -> jnp.ndarray:
        circuit = encoder_fn(x)
        classifier = classifier_fn(w)
        
        nq1 = circuit.width()
        nq2 = classifier.width()
        
        nq = max(nq1, nq2)
        qc = qiskit.QuantumCircuit(nq)
        qc.append(circuit.to_instruction(), list(range(nq1)))
        qc.append(classifier.to_instruction(), list(range(nq2)))

        histogram = simulate(qc)
        
        return histogram_to_category(histogram)

    
    def loss(params: optax.Params, batch: jnp.ndarray, labels: jnp.ndarray) -> jnp.ndarray:
        predictions = circuit_wrapper(batch, params)
        
        y_pred = jax.nn.one_hot(y % 2, 2).astype(jnp.float32).reshape(len(labels), 2)
        loss_value = optax.sigmoid_binary_cross_entropy(y_hat, labels).sum(axis=-1)

        return loss_value.mean()

    def fit(params: optax.Params, optimizer: optax.GradientTransformation) -> optax.Params:
        opt_state = optimizer.init(params)

        @jax.jit
        def step(params, opt_state, batch, labels):
            loss_value, grads = jax.value_and_grad(loss)(params, batch, labels)
            updates, opt_state = optimizer.update(grads, opt_state, params)
            params = optax.apply_updates(params, updates)
            return params, opt_state, loss_value

        for i in range(epochs):

            batch_index = np.random.randint(0, len(y), (batch_size,))
            x_train_batch = X[batch_index]
            y_train_batch = y[batch_index]


            params, opt_state, loss_value = step(params, opt_state, x_train_batch, y_train_batch)
            losses.append(loss_value)
            if i % 100 == 0:
                print(f'step {i}, loss: {loss_value}')

            return params, losses

    
    initial_params = {
        'w': jax.random.normal(shape=[16, n_layers], key=jax.random.PRNGKey(0)),
    }
    
    optimizer = optax.adam(learning_rate=1e-2)
    
    optimal_params, losses = fit(initial_params, optimizer)
    
    optimal_classifier = classifier_fn(optimal_params)
    
    return optimal_classifier, losses

# %%
X = np.load('data/images.npy')
y = np.load('data/labels.npy')
y_reshape = jax.nn.one_hot(y % 2, 2).astype(jnp.float32).reshape(2000, 2)

X_train, X_test, y_train, y_test = train_test_split(X, y_reshape, test_size=0.33, random_state=42)

circuit_weights, losses = run_training(X_train, y_train, frqi, weight_layer)
# Out:
# ---------------------------------------------------------------------------
# CircuitError                              Traceback (most recent call last)
# Cell In[13], line 7
#       3 y_reshape = jax.nn.one_hot(y % 2, 2).astype(jnp.float32).reshape(2000, 2)
#       5 X_train, X_test, y_train, y_test = train_test_split(X, y_reshape, test_size=0.33, random_state=42)
# ----> 7 circuit_weights, losses = run_training(X_train, y_train, frqi, weight_layer)
#
# Cell In[12], line 81, in run_training(X, y, encoder_fn, classifier_fn, backend)
#      75 initial_params = {
#      76     'w': jax.random.normal(shape=[16, n_layers], key=jax.random.PRNGKey(0)),
#      77 }
#      79 optimizer = optax.adam(learning_rate=1e-2)
# ---> 81 optimal_params, losses = fit(initial_params, optimizer)
#      83 optimal_classifier = classifier_fn(optimal_params)
#      85 return optimal_classifier, losses
#
# Cell In[12], line 67, in run_training.<locals>.fit(params, optimizer)
#      63 x_train_batch = X[batch_index]
#      64 y_train_batch = y[batch_index]
# ---> 67 params, opt_state, loss_value = step(params, opt_state, x_train_batch, y_train_batch)
#      68 losses.append(loss_value)
#      69 if i % 100 == 0:
#
#     [... skipping hidden 12 frame]
#
# Cell In[12], line 55, in run_training.<locals>.fit.<locals>.step(params, opt_state, batch, labels)
#      53 @jax.jit
#      54 def step(params, opt_state, batch, labels):
# ---> 55     loss_value, grads = jax.value_and_grad(loss)(params, batch, labels)
#      56     updates, opt_state = optimizer.update(grads, opt_state, params)
#      57     params = optax.apply_updates(params, updates)
#
#     [... skipping hidden 8 frame]
#
# Cell In[12], line 43, in run_training.<locals>.loss(params, batch, labels)
#      42 def loss(params: optax.Params, batch: jnp.ndarray, labels: jnp.ndarray) -> jnp.ndarray:
# ---> 43     predictions = circuit_wrapper(batch, params)
#      45     y_pred = jax.nn.one_hot(y % 2, 2).astype(jnp.float32).reshape(len(labels), 2)
#      46     loss_value = optax.sigmoid_binary_cross_entropy(y_hat, labels).sum(axis=-1)
#
# Cell In[12], line 26, in run_training.<locals>.circuit_wrapper(x, w)
#      25 def circuit_wrapper(x: jnp.ndarray, w: jnp.ndarray) -> jnp.ndarray:
# ---> 26     circuit = encoder_fn(x)
#      27     classifier = classifier_fn(w)
#      29     nq1 = circuit.width()
#
# File ~/2023_IonQ_Remote/circuits/encoderFRQI.py:27, in encode(image)
#      25 for x in range(len(image)):
#      26     for y in range(len(image[x])):
# ---> 27         qc.cry(0.5*pi*image[x][y],np.arange(qbits-1),qbits-1)
#      28         qc.barrier()
#      30 qc=transpile(qc)
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/quantumcircuit.py:3315, in QuantumCircuit.cry(self, theta, control_qubit, target_qubit, label, ctrl_state)
#    3296 """Apply :class:`~qiskit.circuit.library.CRYGate`.
#    3297
#    3298 For the full matrix form of this gate, see the underlying gate documentation.
#    (...)
#    3310     A handle to the instructions created.
#    3311 """
#    3312 from .library.standard_gates.ry import CRYGate
#    3314 return self.append(
# -> 3315     CRYGate(theta, label=label, ctrl_state=ctrl_state), [control_qubit, target_qubit], []
#    3316 )
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/library/standard_gates/ry.py:181, in CRYGate.__init__(self, theta, label, ctrl_state)
#     167 def __init__(
#     168     self,
#     169     theta: ParameterValueType,
#     170     label: Optional[str] = None,
#     171     ctrl_state: Optional[Union[str, int]] = None,
#     172 ):
#     173     """Create new CRY gate."""
#     174     super().__init__(
#     175         "cry",
#     176         2,
#     177         [theta],
#     178         num_ctrl_qubits=1,
#     179         label=label,
#     180         ctrl_state=ctrl_state,
# --> 181         base_gate=RYGate(theta),
#     182     )
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/library/standard_gates/ry.py:54, in RYGate.__init__(self, theta, label)
#      52 def __init__(self, theta: ParameterValueType, label: Optional[str] = None):
#      53     """Create new RY gate."""
# ---> 54     super().__init__("ry", 1, [theta], label=label)
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/gate.py:38, in Gate.__init__(self, name, num_qubits, params, label)
#      29 """Create a new gate.
#      30
#      31 Args:
#    (...)
#      35     label: An optional label for the gate.
#      36 """
#      37 self.definition = None
# ---> 38 super().__init__(name, num_qubits, 0, params, label=label)
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/instruction.py:105, in Instruction.__init__(self, name, num_qubits, num_clbits, params, duration, unit, label)
#     102 self._duration = duration
#     103 self._unit = unit
# --> 105 self.params = params
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/instruction.py:223, in Instruction.params(self, parameters)
#     221     self._params.append(single_param)
#     222 else:
# --> 223     self._params.append(self.validate_parameter(single_param))
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit/circuit/gate.py:234, in Gate.validate_parameter(self, parameter)
#     232     return parameter.item()
#     233 else:
# --> 234     raise CircuitError(f"Invalid param type {type(parameter)} for gate {self.name}.")
#
# CircuitError: "Invalid param type <class 'jax.interpreters.partial_eval.DynamicJaxprTracer'> for gate ry."
