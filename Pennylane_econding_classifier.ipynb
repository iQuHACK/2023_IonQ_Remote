# %%
import cirq
import numpy as np
import pickle
import json
import os
from collections import Counter
from sklearn.metrics import mean_squared_error

#define utility functions

def simulate(circuit: cirq.Circuit) -> dict:
    """This funcion simulate a cirq circuit (without measurement) and output results in the format of histogram.
    """
    simulator = cirq.Simulator()
    result = simulator.simulate(circuit)
    
    state_vector=result.final_state_vector
    
    histogram = dict()
    for i in range(len(state_vector)):
        population = abs(state_vector[i]) ** 2
        if population > 1e-9:
            histogram[i] = population
    
    return histogram


def histogram_to_category(histogram):
    """This function take a histogram representations of circuit execution results, and process into labels as described in 
    the problem description."""
    assert abs(sum(histogram.values())-1)<1e-8
    positive=0
    for key in histogram.keys():
        digits = bin(int(key))[2:].zfill(20)
        if digits[-1]=='0':
            positive+=histogram[key]
        
    return positive

def count_gates(circuit: cirq.Circuit):
    """Returns the number of 1-qubit gates, number of 2-qubit gates, number of 3-qubit gates...."""
    counter=Counter([len(op.qubits) for op in circuit.all_operations()])
    
    #feel free to comment out the following two lines. But make sure you don't have k-qubit gates in your circuit
    #for k>2
    for i in range(2,20):
        assert counter[i]==0
        
    return counter

def image_mse(image1,image2):
    # Using sklearns mean squared error:
    # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html
    return mean_squared_error(image1, image2)

# %%
#load the mock data (for testing only)
files=os.listdir("mock_data")
dataset=list()
for file in files:
    with open('mock_data/'+file, "r") as infile:
        loaded = json.load(infile)
        dataset.append(loaded)

# %%
#load the actual hackthon data (fashion-mnist)
images=np.load('data/images.npy')
labels=np.load('data/labels.npy')
#you can visualize it
import matplotlib.pyplot as plt
plt.imshow(images[1], cmap=plt.get_cmap('gray'))

# %%
#num_image=len(images)
#new_image=[]
#for i in range(num_image):
#    new_image.append(images[i].resize(16,16))

# %%
import scipy
from qiskit.execute_function import execute

num_image=len(images)
noramliz_const=np.max(num_image)
for i in range(num_image):
    images[i]=images[i]/noramliz_const
    
input_data=images
Output_data=labels

# %%
outputdata=[]
for i in range(num_image):
    if labels[i] == True:
        outputdata.append(1)
    else:
        outputdata.append(0)
outputdata=np.array(outputdata)

# %%
def Image_2_state(image):
    L,W=np.shape(image)
    num_q=int(np.ceil(np.log(L*W)/np.log(2)))
    cf=np.zeros((2**num_q),dtype=float)
    flattern_im=image.flatten()
    for i in range(L*W):
        cf[i]=flattern_im[i]
    norm_const=scipy.linalg.norm(cf)
    if norm_const==0:
        cf[0]=1
        return cf
    cf=cf/norm_const
    return cf

# %%
import qiskit
from qiskit import  transpile
from qiskit import BasicAer
import torch
from torch.autograd import Function
#from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from pennylane.optimize import NesterovMomentumOptimizer, AdagradOptimizer
from pennylane import numpy as np
from pennylane import math
import pennylane as qml


backend = BasicAer.get_backend('statevector_simulator')
def encode_qiskit(image):
    if isinstance(image, list):
        image=np.array(image)
    L,W=np.shape(image)
    num_q=int(np.ceil(np.log(L*W)/np.log(2)))
    state_vector=Image_2_state(image)
    q_indx=[i for i in range(num_q)]
    qml.QubitStateVector(state_vector,wires=q_indx)

# %%
def var_ansatz(weights,num_q,num_rep):
    """
    rx, rz var ansatz
    """
    num_w=len(weights)
    for i in range(num_rep):
        for j in range(num_q):
            qml.RX(weights[i*2*num_q+2*j],wires=j)
            qml.RZ(weights[i*2*num_q+2*j+1],wires=j)
        for j in range(num_q-1):
            qml.CNOT(wires=[j,j+1])
    for j in range(num_q):
        qml.RX(weights[num_q*2*num_rep+2*j],wires=j)
        qml.RZ(weights[num_q*2*num_rep+2*j],wires=j)
    
            
if isinstance(images[0], list):
    image=np.array(images[0])
else:
    image=images[0]
L,W=np.shape(image)
num_q=int(np.ceil(np.log(L*W)/np.log(2)))    
wires=range(num_q)

dev = qml.device("default.qubit", wires=wires)
@qml.qnode(dev)
def circuit_output(weights, images, num_rep=1):
    """
    num_rep : number of layers
    """
    encode_qiskit(images)
    var_ansatz(weights,num_q,num_rep)

    return  qml.expval(qml.PauliZ(0))

def variational_classifier(weights, images):
    return circuit_output(weights, images)

def cost_1(weights, X, Y):
    #predictions = [variational_classifier(weights, x) for x in X]
    predictions = [(variational_classifier(weights, x)+1)/2 for x in X]
    return square_loss(Y, predictions)

def cost(weights, X, Y):
    predictions = [(variational_classifier(weights, x)+1)/2 for x in X]
    return square_loss(Y, predictions)

def square_loss(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        loss = loss - (l)*np.log(p) - (1-l)*np.log(1 - p) #** 2

    loss = loss / len(labels)
    return loss

def accuracy(labels, predictions):

    loss = 0
    for l, p in zip(labels, predictions):
        if abs(l - p) < 0.5: #1e-5:
            loss = loss + 1
    loss = loss / len(labels)

    return loss

# %%
opt = NesterovMomentumOptimizer(0.3) #AdagradOptimizer() # NesterovMomentumOptimizer(0.3)
batch_size = 200
num_layers=1
#_,num_qubits=encode_qiskit(images[0])
acc_best=0
best_weight=weights_init
weights_init = -0.01 * np.random.randn((num_layers+1)*num_q*2, requires_grad=True)
weights = weights_init
for it in range(200):

    # Update the weights by one optimizer step
    batch_index = np.random.randint(0, len(images), (batch_size,))
    X_batch = images[batch_index]
    Y_batch = outputdata[batch_index]
    weights, _, _ = opt.step(cost, weights, X_batch, Y_batch)

    # Compute accuracy
    print('Calculating batch accuracy')
    predictions = [(np.sign(variational_classifier(weights, x))+1)/2 for x in X_batch]
    acc = accuracy(Y_batch, predictions)
    print('Calculating batch cost')
    print(
        "Iter: {:5d} | Cost: {:0.7f} | Accuracy: {:0.7f} ".format(
            it + 1, cost_1(weights, X_batch, Y_batch), acc
        )
    )
    if acc > acc_best:
        acc_best=acc
        best_weight=weights
# Out:
# Calculating batch accuracy
# Calculating batch cost
# Iter:     1 | Cost: 0.8765387 | Accuracy: 0.2850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:     2 | Cost: 0.8646733 | Accuracy: 0.2850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:     3 | Cost: 0.8681083 | Accuracy: 0.3050000
# Calculating batch accuracy
# Calculating batch cost
# Iter:     4 | Cost: 0.8682080 | Accuracy: 0.2900000
# Calculating batch accuracy
# Calculating batch cost
# Iter:     5 | Cost: 0.8943409 | Accuracy: 0.2750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:     6 | Cost: 0.9167499 | Accuracy: 0.2350000
# Calculating batch accuracy
# Calculating batch cost
# Iter:     7 | Cost: 0.8719678 | Accuracy: 0.2650000
# Calculating batch accuracy
# Calculating batch cost
# Iter:     8 | Cost: 0.8253310 | Accuracy: 0.2700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:     9 | Cost: 0.7602455 | Accuracy: 0.3100000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    10 | Cost: 0.6661180 | Accuracy: 0.6450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    11 | Cost: 0.5760004 | Accuracy: 0.7650000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    12 | Cost: 0.5261224 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    13 | Cost: 0.5172876 | Accuracy: 0.7850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    14 | Cost: 0.5984587 | Accuracy: 0.7150000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    15 | Cost: 0.5782050 | Accuracy: 0.7250000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    16 | Cost: 0.5812680 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    17 | Cost: 0.5364684 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    18 | Cost: 0.5414364 | Accuracy: 0.7850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    19 | Cost: 0.5833427 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    20 | Cost: 0.5556091 | Accuracy: 0.7750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    21 | Cost: 0.5404998 | Accuracy: 0.7850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    22 | Cost: 0.5189137 | Accuracy: 0.7950000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    23 | Cost: 0.5441645 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    24 | Cost: 0.5364645 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    25 | Cost: 0.5257931 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    26 | Cost: 0.5476348 | Accuracy: 0.7500000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    27 | Cost: 0.6208871 | Accuracy: 0.6750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    28 | Cost: 0.5529633 | Accuracy: 0.7400000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    29 | Cost: 0.5545518 | Accuracy: 0.7250000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    30 | Cost: 0.5210770 | Accuracy: 0.7650000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    31 | Cost: 0.5002000 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    32 | Cost: 0.5393692 | Accuracy: 0.7500000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    33 | Cost: 0.4863924 | Accuracy: 0.7750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    34 | Cost: 0.5160312 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    35 | Cost: 0.5122041 | Accuracy: 0.7500000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    36 | Cost: 0.5269757 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    37 | Cost: 0.5548088 | Accuracy: 0.7000000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    38 | Cost: 0.5063661 | Accuracy: 0.7400000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    39 | Cost: 0.4973080 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    40 | Cost: 0.5251470 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    41 | Cost: 0.4969824 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    42 | Cost: 0.5216445 | Accuracy: 0.7350000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    43 | Cost: 0.4791475 | Accuracy: 0.7850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    44 | Cost: 0.4862889 | Accuracy: 0.7750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    45 | Cost: 0.5160366 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    46 | Cost: 0.5204846 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    47 | Cost: 0.5562096 | Accuracy: 0.7200000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    48 | Cost: 0.5082658 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    49 | Cost: 0.5273122 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    50 | Cost: 0.4691814 | Accuracy: 0.7850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    51 | Cost: 0.5174801 | Accuracy: 0.7400000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    52 | Cost: 0.5028093 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    53 | Cost: 0.4335064 | Accuracy: 0.8050000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    54 | Cost: 0.4972287 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    55 | Cost: 0.5160076 | Accuracy: 0.7350000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    56 | Cost: 0.4862606 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    57 | Cost: 0.4777063 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    58 | Cost: 0.5235835 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    59 | Cost: 0.5067736 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    60 | Cost: 0.4498223 | Accuracy: 0.8050000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    61 | Cost: 0.5197615 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    62 | Cost: 0.5077427 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    63 | Cost: 0.4455080 | Accuracy: 0.8100000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    64 | Cost: 0.5250388 | Accuracy: 0.7400000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    65 | Cost: 0.5379779 | Accuracy: 0.7200000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    66 | Cost: 0.4698427 | Accuracy: 0.7950000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    67 | Cost: 0.5079884 | Accuracy: 0.7650000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    68 | Cost: 0.5140016 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    69 | Cost: 0.4977119 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    70 | Cost: 0.5332330 | Accuracy: 0.7200000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    71 | Cost: 0.4826448 | Accuracy: 0.7750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    72 | Cost: 0.5026749 | Accuracy: 0.7650000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    73 | Cost: 0.4878060 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    74 | Cost: 0.5433581 | Accuracy: 0.7150000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    75 | Cost: 0.5287859 | Accuracy: 0.7200000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    76 | Cost: 0.4710277 | Accuracy: 0.7750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    77 | Cost: 0.5329162 | Accuracy: 0.7350000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    78 | Cost: 0.5145301 | Accuracy: 0.7350000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    79 | Cost: 0.5193603 | Accuracy: 0.7350000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    80 | Cost: 0.5558392 | Accuracy: 0.6850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    81 | Cost: 0.5467481 | Accuracy: 0.7350000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    82 | Cost: 0.5032632 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    83 | Cost: 0.5468412 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    84 | Cost: 0.4833949 | Accuracy: 0.7750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    85 | Cost: 0.5252199 | Accuracy: 0.7400000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    86 | Cost: 0.4601489 | Accuracy: 0.7850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    87 | Cost: 0.5153377 | Accuracy: 0.7400000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    88 | Cost: 0.4816737 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    89 | Cost: 0.4839768 | Accuracy: 0.7650000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    90 | Cost: 0.5312133 | Accuracy: 0.7250000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    91 | Cost: 0.5047473 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    92 | Cost: 0.4769206 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    93 | Cost: 0.4568020 | Accuracy: 0.7950000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    94 | Cost: 0.5006024 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    95 | Cost: 0.4474741 | Accuracy: 0.8000000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    96 | Cost: 0.4841137 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    97 | Cost: 0.5223397 | Accuracy: 0.7400000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    98 | Cost: 0.4680872 | Accuracy: 0.7750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:    99 | Cost: 0.5142758 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   100 | Cost: 0.4757969 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   101 | Cost: 0.4964714 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   102 | Cost: 0.4836758 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   103 | Cost: 0.5004645 | Accuracy: 0.7650000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   104 | Cost: 0.5208400 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   105 | Cost: 0.4768854 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   106 | Cost: 0.4871669 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   107 | Cost: 0.4967714 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   108 | Cost: 0.4576279 | Accuracy: 0.7900000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   109 | Cost: 0.5238694 | Accuracy: 0.7350000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   110 | Cost: 0.5766485 | Accuracy: 0.6800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   111 | Cost: 0.4936081 | Accuracy: 0.7650000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   112 | Cost: 0.5207649 | Accuracy: 0.7500000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   113 | Cost: 0.5339274 | Accuracy: 0.7250000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   114 | Cost: 0.4902292 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   115 | Cost: 0.5315867 | Accuracy: 0.7250000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   116 | Cost: 0.4867624 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   117 | Cost: 0.4828524 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   118 | Cost: 0.5282793 | Accuracy: 0.7150000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   119 | Cost: 0.4629758 | Accuracy: 0.7850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   120 | Cost: 0.5469928 | Accuracy: 0.7000000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   121 | Cost: 0.4803503 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   122 | Cost: 0.4927202 | Accuracy: 0.7750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   123 | Cost: 0.4504491 | Accuracy: 0.8050000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   124 | Cost: 0.5352985 | Accuracy: 0.7250000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   125 | Cost: 0.5055115 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   126 | Cost: 0.5637455 | Accuracy: 0.6900000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   127 | Cost: 0.4514988 | Accuracy: 0.7950000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   128 | Cost: 0.5111670 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   129 | Cost: 0.5145585 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   130 | Cost: 0.5063072 | Accuracy: 0.7650000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   131 | Cost: 0.4673530 | Accuracy: 0.7900000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   132 | Cost: 0.4869657 | Accuracy: 0.7750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   133 | Cost: 0.4803416 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   134 | Cost: 0.5500575 | Accuracy: 0.7200000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   135 | Cost: 0.5257696 | Accuracy: 0.7400000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   136 | Cost: 0.5244707 | Accuracy: 0.7500000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   137 | Cost: 0.4954909 | Accuracy: 0.7750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   138 | Cost: 0.5028083 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   139 | Cost: 0.4855882 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   140 | Cost: 0.5207185 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   141 | Cost: 0.5214150 | Accuracy: 0.7350000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   142 | Cost: 0.5220534 | Accuracy: 0.7350000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   143 | Cost: 0.4876124 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   144 | Cost: 0.5394218 | Accuracy: 0.7050000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   145 | Cost: 0.5107076 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   146 | Cost: 0.5644990 | Accuracy: 0.6900000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   147 | Cost: 0.5236255 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   148 | Cost: 0.4938628 | Accuracy: 0.7500000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   149 | Cost: 0.4735575 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   150 | Cost: 0.4807307 | Accuracy: 0.7650000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   151 | Cost: 0.5167298 | Accuracy: 0.7500000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   152 | Cost: 0.4782286 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   153 | Cost: 0.5503413 | Accuracy: 0.7100000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   154 | Cost: 0.4665867 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   155 | Cost: 0.4671124 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   156 | Cost: 0.5240923 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   157 | Cost: 0.5059751 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   158 | Cost: 0.5068106 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   159 | Cost: 0.5147126 | Accuracy: 0.7400000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   160 | Cost: 0.5845204 | Accuracy: 0.6700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   161 | Cost: 0.4696677 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   162 | Cost: 0.4980958 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   163 | Cost: 0.5290182 | Accuracy: 0.7250000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   164 | Cost: 0.5711210 | Accuracy: 0.7100000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   165 | Cost: 0.5036799 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   166 | Cost: 0.5297105 | Accuracy: 0.7350000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   167 | Cost: 0.4623944 | Accuracy: 0.8050000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   168 | Cost: 0.4979410 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   169 | Cost: 0.5429997 | Accuracy: 0.7150000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   170 | Cost: 0.5316102 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   171 | Cost: 0.4696223 | Accuracy: 0.7950000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   172 | Cost: 0.4896120 | Accuracy: 0.7700000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   173 | Cost: 0.4867454 | Accuracy: 0.7850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   174 | Cost: 0.4487716 | Accuracy: 0.7850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   175 | Cost: 0.4345518 | Accuracy: 0.8050000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   176 | Cost: 0.5404539 | Accuracy: 0.7100000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   177 | Cost: 0.4868932 | Accuracy: 0.7600000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   178 | Cost: 0.4557113 | Accuracy: 0.7950000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   179 | Cost: 0.5238241 | Accuracy: 0.7250000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   180 | Cost: 0.4899519 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   181 | Cost: 0.5180654 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   182 | Cost: 0.4889823 | Accuracy: 0.7750000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   183 | Cost: 0.5044422 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   184 | Cost: 0.5273032 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   185 | Cost: 0.5130800 | Accuracy: 0.7500000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   186 | Cost: 0.4989571 | Accuracy: 0.7650000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   187 | Cost: 0.5088119 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   188 | Cost: 0.5025906 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   189 | Cost: 0.4724125 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   190 | Cost: 0.4559915 | Accuracy: 0.7900000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   191 | Cost: 0.4865606 | Accuracy: 0.7800000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   192 | Cost: 0.4952003 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   193 | Cost: 0.5158074 | Accuracy: 0.7450000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   194 | Cost: 0.4963045 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   195 | Cost: 0.5544942 | Accuracy: 0.7100000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   196 | Cost: 0.5658745 | Accuracy: 0.6850000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   197 | Cost: 0.5064178 | Accuracy: 0.7550000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   198 | Cost: 0.5230990 | Accuracy: 0.7300000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   199 | Cost: 0.4553096 | Accuracy: 0.8100000
# Calculating batch accuracy
# Calculating batch cost
# Iter:   200 | Cost: 0.4857090 | Accuracy: 0.7800000

# %%
predictions
# Out:
# [tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(1., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(1., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(1., requires_grad=True),
#  tensor(1., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(1., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True),
#  tensor(0., requires_grad=True)]

# %%
predictions = [(np.sign(variational_classifier(weights, x))+1)/2 for x in images]
acc = accuracy(outputdata, predictions)

# %%
acc
# Out:
# 0.754
